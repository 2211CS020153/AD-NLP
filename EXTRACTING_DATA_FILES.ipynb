# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\g. ram reddy\anaconda3\lib\site-packages (3.0.1)

# %%
import PyPDF2
from PyPDF2 import PdfFileReader

# %%
#Creating a pdf file object
pdf = open(r"C:\Users\G. RAM REDDY\Downloads\file1pdf.pdf","rb")
#creating pdf reader object
pdf_reader = PyPDF2.PdfReader(pdf)
#checking number of pages in a pdf file
print("Number of pages:",len(pdf_reader.pages))
#creating a page object
page = pdf_reader.pages[1]
#finally extracting text from the page
print(page.extract_text())
#closing the pdf file
pdf.close()
# Out:
# Number of pages: 35
#
#
#  Development  Plan for Greater Mumbai 2014‐2034
# Acknowledgements
# The Consultant  wishes to thank the following  individuals  from the Municipal  Corporation  of
# Greater Mumbai for their invaluable  support, insights and contributions  towards ‘Working  Paper 1
# – Preparation  of Base Map’ for the preparation  of the Development  Plan for Greater Mumbai
# 2014‐34.
#  Mr. Subodh Kumar, IAS, Municipal  Commissioner;
#  Mr. Rajeev Kuknoor, Chief Engineer Development  Plan;
#  Mr. Sudhir Ghate, Deputy Chief Engineer Development  Plan;
#  Mr. A.G. Marathe, Deputy Chief Engineer Development  Plan;
#  Mr. R. Balachandran,  Executive  Engineer and Town Planning Officer, Development  Plan.
#  Our gratitude  to the following  experts for their invaluable  insights and support:
# 
# Mr. V.K Phatak, Former Chief Town Planner (MMRDA);
#  Mr. A.N Kale, Former Chief Engineer, (DP);
#  Mr. A. S Jain Former Dy. Chief Engineer, (DP).
#  We wish to especially  thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren
# Daftardar,  Ms. Anita Naik for their continual  support since the
#  beginning  of the project and their
# help towards familiarization  and data collection.  They have been instrumental  in helping to
# contact various MCGM departments  as well as in helping to establish contact with personnel  from
# other government  departments  and organizations.  Many thanks for the MCGM team, for
# deploying  personnel,  particularly  Mr. Prasad Gharat, on extensive  field visits that have helped in
# understanding  actual ground conditions.
#
# We apologize  if we have inadvertently  omitted anyone to whom acknowledgement  is due. We hope
# and anticipate  the work's usefulness  for the intended purpose.

# %%
import PyPDF2, urllib , nltk
from io import BytesIO
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
wFile = urllib.request.urlopen('http://www.udri.org/pdf/02%20working%20paper%201.pdf')
pdfreader = PyPDF2.PdfReader(BytesIO(wFile.read()))

# %%
#extracting page 2 of the docuemnt

pageObj = pdfreader.pages[2]

page2 = pageObj.extract_text()

#Cleaning the text

punctuations = ['(',')',';',':','[',']',',','...','.']

tokens = word_tokenize(page2)

stop_words = stopwords.words('english')

keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
#  'Daftardar',
#  'Ms.',
#  'Anita',
#  'Naik',
#  'continual',
#  'support',
#  'since',
#  'beginning',
#  'project',
#  'help',
#  'towards',
#  'familiarization',
#  'data',
#  'collection',
#  'They',
#  'instrumental',
#  'helping',
#  'contact',
#  'various',
#  'MCGM',
#  'departments',
#  'well',
#  'helping',
#  'establish',
#  'contact',
#  'personnel',
#  'government',
#  'departments',
#  'organizations',
#  'Many',
#  'thanks',
#  'MCGM',
#  'team',
#  'deploying',
#  'personnel',
#  'particularly',
#  'Mr.',
#  'Prasad',
#  'Gharat',
#  'extensive',
#  'field',
#  'visits',
#  'helped',
#  'understanding',
#  'actual',
#  'ground',
#  'conditions',
#  '........................................................................................',
#  '3',
#  'BEST',
#  '...............................................................................................................................',
#  '.................',
#  '5',
#  'Brihanmumbai',
#  'Electric',
#  'Supply',
#  'Transport',
#  'Undertaking',
#  '..............................................................',
#  '5',
#  'CIDCO',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'City',
#  'Industrial',
#  'Development',
#  'Corporation',
#  '...............................................................................',
#  '5',
#  'CTP',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Comprehensive',
#  'Transportation',
#  'Plan',
#  '...............................................................................................',
#  '5',
#  'DP',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Development',
#  'Plan',
#  '..........................................................................................................................',
#  '5',
#  'DPGM34',
#  '...............................................................................................................................',
#  '..........',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2034',
#  '.......................................................................................',
#  '5',
#  'DCR',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Development',
#  'Control',
#  'Regulations',
#  '...................................................................................................',
#  '5',
#  'DGPS',
#  '...........................................................................................................................',
#  '....................',
#  '5',
#  'Digital',
#  'Global',
#  'Positioning',
#  'System',
#  '...................................................................................................',
#  '5',
#  'DPGM',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '...........................................................................................',
#  '5',
#  'ELU',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Existing',
#  'Land',
#  'use',
#  '.............................................................................................................................',
#  '5',
#  'FSI',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Floor',
#  'Space',
#  'Index',
#  '............................................................................................................................',
#  '5',
#  'GIS',
#  '...............................................................................................................................',
#  '...................',
#  '5']

# %%
name_list = list()

check =  ['Mr.', 'Mrs.', 'Ms.']

for idx, token in enumerate(tokens):

    if token.startswith(tuple(check)) and idx < (len(tokens)-1):

        name = token + tokens[idx+1] + ' ' +  tokens[idx+2]

        name_list.append(name)

 

print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
wFile.close()

# %%
name_list = list()

check =  ['Mr.', 'Mrs.', 'Ms.']

for idx, token in enumerate(tokens):

    if token.startswith(tuple(check)) and idx < (len(tokens)-1):

        name = token + tokens[idx+1] + ' ' +  tokens[idx+2]

        name_list.append(name)
print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
# install docx library

# !pip install python-docx
# Out:
# Collecting python-docx
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/3e/3d/330d9efbdb816d3f60bf2ad92f05e1708e4a1b9abe80461ac3444c83f749/python_docx-1.1.2-py3-none-any.whl.metadata
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting lxml>=3.1.0 (from python-docx)
#   Obtaining dependency information for lxml>=3.1.0 from https://files.pythonhosted.org/packages/c3/b5/91c2249bfac02ee514ab135e9304b89d55967be7e53e94a879b74eec7a5c/lxml-5.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading lxml-5.3.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\g. ram reddy\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ----- ---------------------------------- 30.7/244.3 kB ? eta -:--:--
#    --------------- ------------------------ 92.2/244.3 kB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 122.9/244.3 kB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 194.6/244.3 kB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 194.6/244.3 kB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 194.6/244.3 kB 1.5 MB/s eta 0:00:01
#    -------------------------------------- 244.3/244.3 kB 833.0 kB/s eta 0:00:00
# Downloading lxml-5.3.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.8 MB 655.4 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/3.8 MB 654.9 kB/s eta 0:00:06
#    -- ------------------------------------- 0.3/3.8 MB 1.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.4/3.8 MB 1.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.4/3.8 MB 1.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/3.8 MB 1.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.5/3.8 MB 1.2 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 1.2 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 1.2 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 1.1 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 1.1 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 1.1 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 944.8 kB/s eta 0:00:04
#    ------ --------------------------------- 0.6/3.8 MB 944.8 kB/s eta 0:00:04
#    ------ --------------------------------- 0.7/3.8 MB 838.1 kB/s eta 0:00:04
#    ------- -------------------------------- 0.7/3.8 MB 803.9 kB/s eta 0:00:04
#    ------- -------------------------------- 0.7/3.8 MB 770.0 kB/s eta 0:00:05
#    ------- -------------------------------- 0.7/3.8 MB 786.0 kB/s eta 0:00:04
kB/s eta 0:00:01
#    ------------------------------------- -- 3.6/3.8 MB 339.3 kB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.8 MB 338.7 kB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.8 MB 339.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 341.0 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 341.0 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 339.9 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 341.3 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 341.3 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 341.3 kB/s eta 0:00:01
#    ---------------------------------------  3.7/3.8 MB 336.9 kB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 338.8 kB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 338.8 kB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 338.8 kB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 337.7 kB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 337.7 kB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 335.8 kB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 335.4 kB/s eta 0:00:00
# Installing collected packages: lxml, python-docx
# Successfully installed lxml-5.3.0 python-docx-1.1.2

# %%
#Import library

import docx

# %%
#Creating a word file object
doc = open(r"C:\Users\G. RAM REDDY\Downloads\DAA Leetcode solutions.docx","rb")
#creating word reader object
document = docx.Document(doc)

# %%
docu=""

for para in document.paragraphs:

    docu += para.text

#to see the output call docu

print(docu)
# Out:
# 1. Find the index of the Occurrence String - #include <string>using namespace std;class Solution {public:    int strStr(string haystack, string needle) {        // Find the position of the first occurrence of needle in haystack        size_t pos = haystack.find(needle);                // If found, return the position; otherwise, return -1        return (pos != string::npos) ? pos : -1;    }};3. Square Root –#include <iostream>using namespace std;class Solution {public:    int mySqrt(int x) {        if (x == 0 || x == 1) return x; // Handle edge cases                int left = 0, right = x, result = 0;                while (left <= right) {            long long mid = left + (right - left) / 2; // Use long long to avoid overflow            long long square = mid * mid;                        if (square == x) {                return mid; // Perfect square            } else if (square < x) {                result = mid; // Update result                left = mid + 1; // Search in the right half            } else {                right = mid - 1; // Search in the left half            }        }                return result; // Return the largest integer whose square <= x    }};4. Largest Number --#include <vector>#include <string>#include <algorithm>using namespace std;class Solution {public:    string largestNumber(vector<int>& nums) {        vector<string> strNums;        for (int num : nums) {            strNums.push_back(to_string(num));        }        auto compare = [](const string& a, const string& b) {            return a + b > b + a;        };        sort(strNums.begin(), strNums.end(), compare);        string result;        for (const string& str : strNums) {            result += str;        }        if (result[0] == '0') {            return "0";        }        return result;    }};5.valid parentheses – #include <iostream>#include <stack>#include <string>using namespace std;class Solution {public:    bool isValid(string s) {        stack<char> stack;                for (char c : s) {            // If the character is an opening bracket, push it onto the stack            if (c == '(' || c == '{' || c == '[') {                stack.push(c);            }             // If the character is a closing bracket, check if it matches the top of the stack            else if (c == ')' || c == '}' || c == ']') {                if (stack.empty()) {                    return false; // No opening bracket to match with                }                char top = stack.top();                stack.pop();                                // Check if the top of the stack matches the corresponding opening bracket                if ((c == ')' && top != '(') || (c == '}' && top != '{') || (c == ']' && top != '[')) {                    return false;                }            }        }                // If the stack is empty, all brackets were matched, otherwise return false        return stack.empty();    }};6.Merge Two sorted Lists – #include <iostream>#include <vector>  // Include the ListNode headerusing namespace std;class Solution {public:    ListNode* mergeTwoLists(ListNode* list1, ListNode* list2) {        ListNode* dummy = new ListNode(0);  // Create a dummy node to start the merged list        ListNode* current = dummy;  // Pointer to build the new list        // Traverse both lists        while (list1 != nullptr && list2 != nullptr) {            if (list1->val <= list2->val) {                current->next = list1;  // Attach list1 node to merged list                list1 = list1->next;     // Move the list1 pointer forward            } else {                current->next = list2;  // Attach list2 node to merged list                list2 = list2->next;     // Move the list2 pointer forward            }            current = current->next;  // Move the current pointer forward in the merged list        }        // If there are remaining nodes in list1 or list2, attach them        if (list1 != nullptr) {            current->next = list1;    ...

# %%
#  output paragraph number and paragraph content 

for i in range(len(document.paragraphs)):

    print("The content of the paragraph "+ str(i)+" is ：" + document.paragraphs[i].text+"\n")
# Out:
# The content of the paragraph 0 is ：
#
# The content of the paragraph 1 is ：1. Find the index of the Occurrence String -
#
# The content of the paragraph 2 is ：
#
# The content of the paragraph 3 is ：#include <string>
#
# The content of the paragraph 4 is ：using namespace std;
#
# The content of the paragraph 5 is ：
#
# The content of the paragraph 6 is ：class Solution {
#
# The content of the paragraph 7 is ：public:
#
# The content of the paragraph 8 is ：    int strStr(string haystack, string needle) {
#
# The content of the paragraph 9 is ：        // Find the position of the first occurrence of needle in haystack
#
# The content of the paragraph 10 is ：        size_t pos = haystack.find(needle);
#
# The content of the paragraph 11 is ：
#
# The content of the paragraph 12 is ：        // If found, return the position; otherwise, return -1
#
# The content of the paragraph 13 is ：        return (pos != string::npos) ? pos : -1;
#
# The content of the paragraph 14 is ：    }
#
# The content of the paragraph 15 is ：};
#
# The content of the paragraph 16 is ：3. Square Root –
#
# The content of the paragraph 17 is ：#include <iostream>
#
# The content of the paragraph 18 is ：using namespace std;
#
# The content of the paragraph 19 is ：
#
# The content of the paragraph 20 is ：class Solution {
#
# The content of the paragraph 21 is ：public:
#
# The content of the paragraph 22 is ：    int mySqrt(int x) {
#
# The content of the paragraph 23 is ：        if (x == 0 || x == 1) return x; // Handle edge cases
#
# The content of the paragraph 24 is ：
#
# The content of the paragraph 25 is ：        int left = 0, right = x, result = 0;
#
# The content of the paragraph 26 is ：
#
# The content of the paragraph 27 is ：        while (left <= right) {
#
# The content of the paragraph 28 is ：            long long mid = left + (right - left) / 2; // Use long long to avoid overflow
#
# The content of the paragraph 29 is ：            long long square = mid * mid;
#
# The content of the paragraph 30 is ：
#
# The content of the paragraph 31 is ：            if (square == x) {
#
# The content of the paragraph 32 is ：                return mid; // Perfect square
#
# The content of the paragraph 33 is ：            } else if (square < x) {
#
# The content of the paragraph 34 is ：                result = mid; // Update result
#
# The content of the paragraph 35 is ：                left = mid + 1; // Search in the right half
#
# The content of the paragraph 36 is ：            } else {
#
# The content of the paragraph 37 is ：                right = mid - 1; // Search in the left half
#
# The content of the paragraph 38 is ：            }
#
# The content of the paragraph 39 is ：        }
#
# The content of the paragraph 40 is ：
#
# The content of the paragraph 41 is ：        return result; // Return the largest integer whose square <= x
#
# The content of the paragraph 42 is ：    }
#
# The content of the paragraph 43 is ：};
#
# The content of the paragraph 44 is ：
#
# The content of the paragraph 45 is ：
#
# The content of the paragraph 46 is ：
#
# The content of the paragraph 47 is ：4. Largest Number --
#
# The content of the paragraph 48 is ：#include <vector>
#
# The content of the paragraph 49 is ：#include <string>
#
# The content of the paragraph 50 is ：#include <algorithm>
#
# The content of the paragraph 51 is ：using namespace std;
#
# The content of the paragraph 52 is ：
#
# The content of the paragraph 53 is ：class Solution {
#
# The content of the paragraph 54 is ：public:
#
# The content of the paragraph 55 is ：    string largestNumber(vector<int>& nums) {
#
# The content of the paragraph 56 is ：        vector<string> strNums;
#
# The content of the paragraph 57 is ：        for (int num : nums) {
#
# The content of the paragraph 58 is ：            strNums.push_back(to_string(num));
#
# The content of the paragraph 59 is ：        }
#
# The content of the paragraph 60 is ：
#
# The content of the paragraph 61 is ：        auto compare = [](const string& a, const string& b) {
#
# The content of the paragraph 62 is ：            return a + b > b + a;
#
# The content of the paragraph 63 is ：        };
#
# The content of the paragraph 64 is ：
#
# The content of the paragraph 65 is ：        sort(strNums.begin(), strNums.end(), compare);
#
# The content of the paragraph 66 is ：
#
# The content of the paragraph 67 is ：        string result;
#
# The content of the paragraph 68 is ：        for (const string& str : strNums) {
#
# The content of the paragraph 69 is ：            result += str;
#
# The content of the paragraph 70 is ：        }
#
# The content of the paragraph 71 is ：
#
# The content of the paragraph 72 is ：        if (result[0] == '0') {
#
# The content of the paragraph 73 is ：            return "0";
#
# The content of the paragraph 74 is ：        }
#
# The content of the paragraph 75 is ：
#
# The content of the paragraph 76 is ：        return result;
#
# The content of the paragraph 77 is ：    }
#
# The content of the paragraph 78 is ：};
#
# The content of the paragraph 79 is ：5.valid parentheses –
#
# The content of the paragraph 80 is ：#include <iostream>
#
# The content of the paragraph 81 is ：#include <stack>
#
# The content of the paragraph 82 is ：#include <string>
#
# The content of the paragraph 83 is ：using namespace std;
#
# The content of the paragraph 84 is ：
#
# The content of the paragraph 85 is ：class Solution {
#
# The content of the paragraph 86 is ：public:
#
# The content of the paragraph 87 is ：    bool isValid(string s) {
#
# The content of the paragraph 88 is ：        stack<char> stack;
#
# The content of the paragraph 89 is ：
#
# The content of the paragraph 90 is ：        for (char c : s) {
#
# The content of the paragraph 91 is ：            // If the character is an opening bracket, push it onto the stack
#
# The content of the paragraph 92 is ：            if (c == '(' || c == '{' || c == '[') {
#
# The content of the paragraph 93 is ：                stack.push(c);
#
# The content of the paragraph 94 is ：            }
#
# The content of the paragraph 95 is ：            // If the character is a closing bracket, check if it matches the top of the stack
#
# The content of the paragraph 96 is ：            else if (c == ')' || c == '}' || c == ']') {
#
# The content of the paragraph 97 is ：                if (stack.empty()) {
#
# The content of the paragraph 98 is ：                    return false; // No opening bracket to match with
#
# The content of the paragraph 99 is ：                }
#
# The content of the paragraph 100 is ：                char top = stack.top();
#
# The content of the paragraph 101 is ：                stack.pop();
#
# The content of the paragraph 102 is ：
#
# The content of the paragraph 103 is ：                // Check if the top of the stack matches the corresponding opening bracket
#
# The content of the paragraph 104 is ：                if ((c == ')' && top != '(') || (c == '}' && top != '{') || (c == ']' && top != '[')) {
#
# The content of the paragraph 105 is ：                    return false;
#
# The content of the paragraph 106 is ：                }
#
# The content of the paragraph 107 is ：            }
#
# The content of the paragraph 108 is ：        }
#
# The content of the paragraph 109 is ：
#
# The content of the paragraph 110 is ：        // If the stack is empty, all brackets were matched, otherwise return false
#
# The content of the paragraph 111 is ：        return stack.empty();
#
# The content of the paragraph 112 is ：    }
#
# The content of the paragraph 113 is ：};
#
# The content of the paragraph 114 is ：6.Merge Two sorted Lists –
#
# The content of the paragraph 115 is ：#include <iostream>
#
# The content of the paragraph 116 is ：#include <vector>
#
# The content of the paragraph 117 is ：  // Include the ListNode header
#
# The content of the paragraph 118 is ：using namespace std;
#
# The content of the paragraph 119 is ：
#
# The content of the paragraph 120 is ：class Solution {
#
# The content of the paragraph 121 is ：public:
#
# The content of the paragraph 122 is ：    ListNode* mergeTwoLists(ListNode* list1, ListNode* list2) {
#
# The content of the paragraph 123 is ：        ListNode* dummy = new ListNode(0);  // Create a dummy node to start the merged list
#
# The content of the paragraph 124 is ：        ListNode* current = dummy;  // Pointer to build the new list
#
# The content of the paragraph 125 is ：
#
# The content of the paragraph 126 is ：        // Traverse both lists
#
# The content of the paragraph 127 is ：        while (list1 != nullptr && list2 != nullptr) {
#
# The content of the paragraph 128 is ：            if (list1->val <= list2->val) {
#
# The content of the paragraph 129 is ：                current->next = list1;  // Attach list1 node to merged list
#
# The content of the paragraph 130 is ：                list1 = list1->next;     // Move the list1 pointer forward
#
# The content of the paragraph 131 is ：            } else {
#
# The content of the paragraph 132 is ：                current->next = list2;  // Attach list2 node to merged list
#
# The content of the paragraph 133 is ：                list2 = list2->next;     // Move the list2 pointer forward
#
# The content of the paragraph 134 is ：            }
#
# The content of the paragraph 135 is ：            current = current->next;  // Move the current pointer forward in the merged list
#
# The content of the paragraph 136 is ：        }
#
# The content of the paragraph 137 is ：
#
# The content of the paragraph 138 is ：        // If there are remaining nodes in list1 or list2, attach them
#
# The content of the paragraph 139 is ：        if (list1 != nullptr) {
#
# The content of the paragraph 140 is ：            current->next = list1;
#
# The content of the paragraph 141 is ：        } else if (list2 != nullptr) {
#
# The content of the paragraph 142 is ：            current->next = list2;
#
# The content of the paragraph 143 is ：        }
#
# The content of the paragraph 144 is ：
#
# The content of the paragraph 145 is ：        return dummy->next;  // Return the merged list starting from the first node
#
# The content of the paragraph 146 is ：    }
#
# The content of the paragraph 147 is ：};
#
# The content of the paragraph 148 is ：
#
# The content of the paragraph 149 is ：// Helper function to create a linked list from a vector
#
# The content of the paragraph 150 is ：ListNode* createList(const vector<int>& nums) {
#
# The content of the paragraph 151 is ：    ListNode* head = nullptr;
#
# The content of the paragraph 152 is ：    ListNode* current = nullptr;
#
# The content of the paragraph 153 is ：    for (int num : nums) {
#
# The content of the paragraph 154 is ：        if (!head) {
#
# The content of the paragraph 155 is ：            head = new ListNode(num);
#
# The content of the paragraph 156 is ：            current = head;
#
# The content of the paragraph 157 is ：        } else {
#
# The content of the paragraph 158 is ：            current->next = new ListNode(num);
#
# The content of the paragraph 159 is ：            current = current->next;
#
# The content of the paragraph 160 is ：        }
#
# The content of the paragraph 161 is ：    }
#
# The content of the paragraph 162 is ：    return head;
#
# The content of the paragraph 163 is ：}
#
# The content of the paragraph 164 is ：
#
# The content of the paragraph 165 is ：// Helper function to print the linked list
#
# The content of the paragraph 166 is ：void printList(ListNode* head) {
#
# The content of the paragraph 167 is ：    while (head != nullptr) {
#
# The content of the paragraph 168 is ：        cout << head->val << " ";
#
# The content of the paragraph 169 is ：        head = head->next;
#
# The content of the paragraph 170 is ：    }
#
# The content of the paragraph 171 is ：    cout << endl;
#
# The content of the paragraph 172 is ：}
#
# The content of the paragraph 173 is ：
#
# The content of the paragraph 174 is ：7. Remove duplicates from sorted List –
#
# The content of the paragraph 175 is ：#include <iostream>
#
# The content of the paragraph 176 is ：using namespace std;
#
# The content of the paragraph 177 is ：
#
# The content of the paragraph 178 is ：// Assume ListNode structure is already defined and precompiled.
#
# The content of the paragraph 179 is ：
#
# The content of the paragraph 180 is ：class Solution {
#
# The content of the paragraph 181 is ：public:
#
# The content of the paragraph 182 is ：    ListNode* deleteDuplicates(ListNode* head) {
#
# The content of the paragraph 183 is ：        ListNode* current = head;
#
# The content of the paragraph 184 is ：        while (current != nullptr && current->next != nullptr) {
#
# The content of the paragraph 185 is ：            if (current->val == current->next->val) {
#
# The content of the paragraph 186 is ：                // Skip the duplicate node
#
# The content of the paragraph 187 is ：                current->next = current->next->next;
#
# The content of the paragraph 188 is ：            } else {
#
# The content of the paragraph 189 is ：                // Move to the next node
#
# The content of the paragraph 190 is ：                current = current->next;
#
# The content of the paragraph 191 is ：            }
#
# The content of the paragraph 192 is ：        }
#
# The content of the paragraph 193 is ：        return head;
#
# The content of the paragraph 194 is ：    }
#
# The content of the paragraph 195 is ：};
#
# The content of the paragraph 196 is ：
#
# The content of the paragraph 197 is ：// Helper function to print the linked list
#
# The content of the paragraph 198 is ：void printList(ListNode* head) {
#
# The content of the paragraph 199 is ：    while (head != nullptr) {
#
# The content of the paragraph 200 is ：        cout << head->val << " ";
#
# The content of the paragraph 201 is ：        head = head->next;
#
# The content of the paragraph 202 is ：    }
#
# The content of the paragraph 203 is ：    cout << endl;
#
# The content of the paragraph 204 is ：}
#
# The content of the paragraph 205 is ：
#
# The content of the paragraph 206 is ：
#
# The content of the paragraph 207 is ：
#
# The content of the paragraph 208 is ：8. Finding Peek element –
#
# The content of the paragraph 209 is ：#include <iostream>
#
# The content of the paragraph 210 is ：#include <vector>
#
# The content of the paragraph 211 is ：using namespace std;
#
# The content of the paragraph 212 is ：
#
# The content of the paragraph 213 is ：class Solution {
#
# The content of the paragraph 214 is ：public:
#
# The content of the paragraph 215 is ：    int findPeakElement(vector<int>& nums) {
#
# The content of the paragraph 216 is ：        int left = 0, right = nums.size() - 1;
#
# The content of the paragraph 217 is ：
#
# The content of the paragraph 218 is ：        while (left < right) {
#
# The content of the paragraph 219 is ：            int mid = left + (right - left) / 2;
#
# The content of the paragraph 220 is ：
#
# The content of the paragraph 221 is ：            if (nums[mid] > nums[mid + 1]) {
#
# The content of the paragraph 222 is ：                right = mid;
#
# The content of the paragraph 223 is ：            } else {
#
# The content of the paragraph 224 is ：                left = mid + 1;
#
# The content of the paragraph 225 is ：            }
#
# The content of the paragraph 226 is ：        }
#
# The content of the paragraph 227 is ：
#
# The content of the paragraph 228 is ：        return left;
#
# The content of the paragraph 229 is ：    }
#
# The content of the paragraph 230 is ：};
#
# The content of the paragraph 231 is ：
#
# The content of the paragraph 232 is ：9. Binary Tree : In order traversal –
#
# The content of the paragraph 233 is ：#include <iostream>
#
# The content of the paragraph 234 is ：#include <vector>
#
# The content of the paragraph 235 is ：
#
# The content of the paragraph 236 is ：
#
# The content of the paragraph 237 is ：using namespace std;
#
# The content of the paragraph 238 is ：
#
# The content of the paragraph 239 is ：class Solution {
#
# The content of the paragraph 240 is ：public:
#
# The content of the paragraph 241 is ：    void inorderTraversalHelper(TreeNode* root, vector<int>& result) {
#
# The content of the paragraph 242 is ：        if (root == nullptr) {
#
# The content of the paragraph 243 is ：            return;
#
# The content of the paragraph 244 is ：        }
#
# The content of the paragraph 245 is ：
#
# The content of the paragraph 246 is ：        // Traverse left subtree
#
# The content of the paragraph 247 is ：        inorderTraversalHelper(root->left, result);
#
# The content of the paragraph 248 is ：
#
# The content of the paragraph 249 is ：        // Visit the root node
#
# The content of the paragraph 250 is ：        result.push_back(root->val);
#
# The content of the paragraph 251 is ：
#
# The content of the paragraph 252 is ：        // Traverse right subtree
#
# The content of the paragraph 253 is ：        inorderTraversalHelper(root->right, result);
#
# The content of the paragraph 254 is ：    }
#
# The content of the paragraph 255 is ：
#
# The content of the paragraph 256 is ：    vector<int> inorderTraversal(TreeNode* root) {
#
# The content of the paragraph 257 is ：        vector<int> result;
#
# The content of the paragraph 258 is ：        inorderTraversalHelper(root, result);
#
# The content of the paragraph 259 is ：        return result;
#
# The content of the paragraph 260 is ：    }
#
# The content of the paragraph 261 is ：};
#
# The content of the paragraph 262 is ：
#
# The content of the paragraph 263 is ：
#
# The content of the paragraph 264 is ：
#
# The content of the paragraph 265 is ：
#
# The content of the paragraph 266 is ：10. N-Queens --
#
# The content of the paragraph 267 is ：#include <vector>
#
# The content of the paragraph 268 is ：#include <string>
#
# The content of the paragraph 269 is ：using namespace std;
#
# The content of the paragraph 270 is ：
#
# The content of the paragraph 271 is ：class Solution {
#
# The content of the paragraph 272 is ：public:
#
# The content of the paragraph 273 is ：    vector<vector<string>> solveNQueens(int n) {
#
# The content of the paragraph 274 is ：        vector<vector<string>> solutions;
#
# The content of the paragraph 275 is ：        vector<string> board(n, string(n, '.')); // Initialize an empty n x n board
#
# The content of the paragraph 276 is ：        vector<int> leftRow(n, 0), upperDiag(2 * n - 1, 0), lowerDiag(2 * n - 1, 0);
#
# The content of the paragraph 277 is ：        backtrack(0, n, board, solutions, leftRow, upperDiag, lowerDiag);
#
# The content of the paragraph 278 is ：        return solutions;
#
# The content of the paragraph 279 is ：    }
#
# The content of the paragraph 280 is ：
#
# The content of the paragraph 281 is ：private:
#
# The content of the paragraph 282 is ：    void backtrack(int col, int n, vector<string>& board, vector<vector<string>>& solutions,
#
# The content of the paragraph 283 is ：                   vector<int>& leftRow, vector<int>& upperDiag, vector<int>& lowerDiag) {
#
# The content of the paragraph 284 is ：        if (col == n) {
#
# The content of the paragraph 285 is ：            solutions.push_back(board);
#
# The content of the paragraph 286 is ：            return;
#
# The content of the paragraph 287 is ：        }
#
# The content of the paragraph 288 is ：
#
# The content of the paragraph 289 is ：        for (int row = 0; row < n; ++row) {
#
# The content of the paragraph 290 is ：            if (leftRow[row] == 0 && upperDiag[row + col] == 0 && lowerDiag[row - col + n - 1] == 0) {
#
# The content of the paragraph 291 is ：                board[row][col] = 'Q';
#
# The content of the paragraph 292 is ：                leftRow[row] = upperDiag[row + col] = lowerDiag[row - col + n - 1] = 1;
#
# The content of the paragraph 293 is ：
#
# The content of the paragraph 294 is ：                backtrack(col + 1, n, board, solutions, leftRow, upperDiag, lowerDiag);
#
# The content of the paragraph 295 is ：
#
# The content of the paragraph 296 is ：                // Undo the current placement
#
# The content of the paragraph 297 is ：                board[row][col] = '.';
#
# The content of the paragraph 298 is ：                leftRow[row] = upperDiag[row + col] = lowerDiag[row - col + n - 1] = 0;
#
# The content of the paragraph 299 is ：            }
#
# The content of the paragraph 300 is ：        }
#
# The content of the paragraph 301 is ：    }
#
# The content of the paragraph 302 is ：};
#
# The content of the paragraph 303 is ：
#
# The content of the paragraph 304 is ：
#
# The content of the paragraph 305 is ：

# %%
# Install and import all the necessary libraries

# !pip install bs4
# Out:
# Collecting bs4
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\g. ram reddy\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\g. ram reddy\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import urllib.request as urllib2

from bs4 import BeautifulSoup

# %%
response = urllib2.urlopen('https://en.wikipedia.org/wiki/Natural_language_processing')

html_doc = response.read()

# %%
#Parsing

soup = BeautifulSoup(html_doc, 'html.parser')

# Formating the parsed html file

strhtm = soup.prettify()

# Print few lines

print (strhtm[:5000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Natural language processing - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bb8cccbb-931f-4281-aaf8-3aff8c9effb8","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Natural_language_processing","wgTitle":"Natural language processing","wgCurRevisionId":1274942014,"wgRevisionId":1274942014,"wgArticleId":21652,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All accuracy disputes","Accuracy disputes from December 2013","Harv and Sfn no-target errors","CS1 errors: periodical ignored","CS1 maint: location","Articles with short description","Short description is different from Wikidata","Articles needing additional references from May 2024","All articles needing additional references","All articles with unsourced statements","Articles with unsourced statements from May 2024","Commons category link from Wikidata",
# "Natural language processing","Computational fields of study","Computational linguistics","Speech recognition"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Natural_language_processing","wgRelevantArticleId":21652,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,
# "wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q30642","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site",
# "mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.bootstrap","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visu
